# %%
# %cd nlp

# %%
# !pip install pronouncing bert_score

# %% [markdown]
# ## Part-1 : nlp2025-1_part1 폴더에서 진행되는 내용입니다.

# %%
# %cd /content/nlp/nlp2025-1_part1

# %%
# !python classifier.py --use_gpu

# %%
# !python paraphrase_detection_raw.py --use_gpu

# %%
# !python sonnet_generation.py --use_gpu

# %% [markdown]
# ## Part-2 : nlp2025-1_part2 폴더에서 진행되는 내용입니다.

# %%
# %cd /content/nlp/nlp2025-1_part2

# %%
# !python classifier_base.py --use_gpu

# %%
# !python classifier_cascade.py --use_gpu

# %%
# !python sonnet_generation.py --use_gpu

# %%
# !python paraphrase_detection.py --use_gpu
